# %% [markdown]
# # Lezione 11 - Neural Networks per Regressione
#
# # NEURAL NETWORKS PER REGRESSIONE
# ## Laboratorio di Simulazioni Numeriche - Lezione 11
# ---
#
# ## Descrizione della Lezione
#
# Esploriamo l'uso delle **reti neurali** per problemi di regressione usando **TensorFlow/Keras**. Implementiamo tre diversi modelli neurali per approssimare funzioni di crescente complessità:
#
# 1. **Regressione lineare** con singolo neurone
# 2. **Regressione polinomiale** con rete profonda
# 3. **Funzione trigonometrica 2D** con input multidimensionale
#
# ---
#
# ### Background Teorico
#
# #### Reti Neurali Artificiali
# Una rete neurale è composta da **neuroni artificiali** organizzati in layers. Ogni neurone calcola:
#
# y = σ(w·x + b)
#
# dove:
# - **w**: pesi sinaptici (parametri da apprendere)
# - **b**: bias (termine costante)
# - **σ**: funzione di attivazione (ReLU, sigmoid, tanh, ...)
#
# #### Funzioni di Attivazione
# - **ReLU**: f(x) = max(0, x) - evita vanishing gradient
# - **Linear**: f(x) = x - per output layer in regressione
#
# #### Ottimizzatori
# - **SGD (Stochastic Gradient Descent)**: algoritmo base di discesa del gradiente
# - **Adam**: versione adattiva con momentum e correzione bias
#
# #### Loss Function per Regressione
# **Mean Square Error (MSE)**:
#
# MSE = (1/n) × Σ(y_true - y_pred)²
#
# ---
#
# ## Esercizio 11.1: Regressione Lineare
#
# **Obiettivo**: Utilizzare un singolo neurone per approssimare la funzione lineare:
#
# f(x) = 2x + 1

# %%
# Parametri della funzione target
m = 2  # coefficiente angolare (slope)
q = 1  # intercetta (bias)

# %% [markdown]
# ### Generazione Dataset
#
# Creiamo dataset di training e validation con rumore gaussiano per simulare misure reali:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fissiamo il seed per riproducibilità
np.random.seed(1)

# Generazione dataset di training (1000 punti)
x_train = np.random.uniform(-1, 1, 1000)

# Generazione dataset di validation (50 punti ordinati per visualizzazione)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()

# Funzione target ideale (senza rumore)
y_target = m * x_valid + q

# Parametri del rumore
sigma = 0.1  # deviazione standard del rumore gaussiano

# Dataset con rumore gaussiano (simulano misure reali)
y_train = np.random.normal(m * x_train + q, sigma)
y_valid = np.random.normal(m * x_valid + q, sigma)

# Visualizzazione dataset
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(x_valid, y_target, 'g-', linewidth=2, label='Target: f(x) = 2x + 1')
ax.scatter(x_valid, y_valid, color='red', alpha=0.7, s=30, label='Validation data (noisy)')
ax.set_xlabel('x', fontsize=12)
ax.set_ylabel('y', fontsize=12)
ax.set_title('Dataset per Regressione Lineare', fontsize=14, fontweight='bold')
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print(f"Dataset Info:")
print(f"   • Training samples: {len(x_train)}")
print(f"   • Validation samples: {len(x_valid)}")
print(f"   • Noise σ: {sigma}")
print(f"   • Target function: y = {m}x + {q}")
# Out:
# Dataset Info:
#    • Training samples: 1000
#    • Validation samples: 50
#    • Noise σ: 0.1
#    • Target function: y = 2x + 1

# %% [markdown]
# modello a singolo neurone (sequenziale)

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" #per debuggare e avere output pulito no spam

# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# get a summary of our composed model
model.summary()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ho creato il modello, lo alleno con set di coppie di dati del tipo (x_train, y_train)
# uso ottimizzatore SGD per minimizzare la funzione loss MSE

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6524 - mse: 1.6524 - val_loss: 0.8803 - val_mse: 0.8803
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.7305 - mse: 0.7305 - val_loss: 0.4730 - val_mse: 0.4730
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - loss: 0.4213 - mse: 0.4213 - val_loss: 0.2834 - val_mse: 0.2834
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.2533 - mse: 0.2533 - val_loss: 0.1790 - val_mse: 0.1790
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.1605 - mse: 0.1605 - val_loss: 0.1149 - val_mse: 0.1149
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - loss: 0.1071 - mse: 0.1071 - val_loss: 0.0747 - val_mse: 0.0747
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - loss: 0.0735 - mse: 0.0735 - val_loss: 0.0493 - val_mse: 0.0493
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - loss: 0.0529 - mse: 0.0529 - val_loss: 0.0335 - val_mse: 0.0335
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 0.0380 - mse: 0.0380 - val_loss: 0.0235 - val_mse: 0.0235
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 0.0257 - mse: 0.0257 - val_loss: 0.0170 - val_mse: 0.0170
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 0.0214 - mse: 0.0214 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0106 - val_mse: 0.0106
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 589us/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0079 - val_mse: 0.0079

# %% [markdown]
# verifico i pesi del mio modello per confrontarli con i valori teorici

# %%
# return weights and biases
model.get_weights()
# Out:
# [array([[1.986506]], dtype=float32), array([1.0034578], dtype=float32)]

# %% [markdown]
# testo il modello sul validation set

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
#print('Test accuracy:', score[1])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - mse: 0.0081
#
# Test loss: 0.007924342527985573

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2357e-05 - mse: 9.2357e-05
#
# Test loss: 8.351282303920016e-05

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'], 'go-')
plt.plot(history.history['val_loss'], 'ro-')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.grid('true')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r',label="Model prediction")
plt.plot(x_valid, y_target, color='b',label="Target function")
plt.grid(True)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ho plottato x generate a caso e y_pred predette dal modello

# %% [markdown]
# ### Exercise 11.2

# %% [markdown]
# partendo ed estendendo il modello appena descritto cerchiamo di ottenere un fit del polinomio (ordine 3): $$
# f(x)=4-3x-2x^2+3x^3
# $$
# nel range $x \in [-1,1]$.

# %% [markdown]
# creo nuovi dataset di training e test, più grandi

# %%
import numpy as np

# generate training inputs
np.random.seed(1)
x_train = np.random.uniform(-1, 1, 10000)
x_valid = np.random.uniform(-1, 1, 100)
x_valid.sort()
y_target = 4 - 3 *  x_valid - 2 *  x_valid *  x_valid + 3 *  x_valid *  x_valid * x_valid  # ideal (target) linear function

sigma = 0.1 # noise standard deviation
y_train = np.random.normal(4 - 3 * x_train - 2 * x_train * x_train + 3 * x_train * x_train *x_train  , sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(4 - 3 * x_valid - 2 * x_valid * x_valid + 3 * x_valid * x_valid* x_valid , sigma)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target', color='b')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# creo il modello:

# %%
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(32, input_shape=(1,), activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1,))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 32)             │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 609 (2.38 KB)
#  Trainable params: 609 (2.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# fitto il mio modello in 50 epoche

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=50,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 1.8147 - mse: 1.8147 - val_loss: 0.1611 - val_mse: 0.1611
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 241us/step - loss: 0.1752 - mse: 0.1752 - val_loss: 0.0643 - val_mse: 0.0643
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 259us/step - loss: 0.0730 - mse: 0.0730 - val_loss: 0.0347 - val_mse: 0.0347
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0245 - val_mse: 0.0245
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 278us/step - loss: 0.0299 - mse: 0.0299 - val_loss: 0.0206 - val_mse: 0.0206
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 254us/step - loss: 0.0243 - mse: 0.0243 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step - loss: 0.0221 - mse: 0.0221 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 254us/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 261us/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 264us/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 272us/step - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 267us/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 265us/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 263us/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 265us/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0114 - val_mse: 0.0114
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 270us/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 264us/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 264us/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 259us/step - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 254us/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 252us/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 269us/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 260us/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 256us/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 274us/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 264us/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 260us/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 258us/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 236us/step - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 238us/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 272us/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0164 - val_mse: 0.0164
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 268us/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 262us/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0131 - val_mse: 0.0131

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
#print('Test accuracy:', score[1])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.0122 - mse: 0.0122
#
# Test loss: 0.013145535252988338

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'], 'go-')
plt.plot(history.history['val_loss'], 'ro-')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.grid('true')
plt.show()

# %%
x_predicted = np.random.uniform(-1.5, 1.5, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r', label= "Model prediction")
plt.axvline(1., color = 'orange', linestyle = '--')
plt.axvline(-1., color = 'orange', linestyle = '--')
x_predicted.sort()
y_target_ext = 4 - 3 *  x_predicted - 2 *  x_predicted *  x_predicted + 3 *  x_predicted *  x_predicted * x_predicted 
plt.plot(x_predicted, y_target_ext, color='b',label="Target function")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ### Exercise 11.3

# %% [markdown]
# estendiamo ancora il modello per provare a fittare una funzione trigonometrica:
# $f(x,y) = \sin(x^2+y^2)$ nel range $x \in [-3/2,3/2]$, $y \in [-3/2,3/2]$.

# %%
# generate training inputs
np.random.seed(1)
x_train = np.random.uniform(low=-3./2, high=3./2, size=(10000, 2))
x_valid = np.random.uniform(low=-3./2, high=3./2, size=(1000, 2))
#x_valid.sort
y_target = np.sin(x_valid[:, 0]**2 + x_valid[:, 1]**2)

sigma = 0.1 # noise standard deviation
y_train = np.random.normal(np.sin(x_train[:, 0]**2 + x_train[:, 1]**2), scale=sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(np.sin(x_valid[:, 0]**2 + x_valid[:, 1]**2), scale=sigma)

from mpl_toolkits.mplot3d import Axes3D

# Coordinate
x = x_valid[:, 0]
y = x_valid[:, 1]
z_target = y_target
z_valid = y_valid

# Plot 3D
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

#ax.scatter(x, y, z_target,color="blue", label='target', alpha=0.6)
ax.scatter(x, y, z_valid, color='red', label='validation data', alpha=0.6, s=20)

# 1. Crea griglia regolare
x_grid = np.linspace(min(x), max(x), 100)
y_grid = np.linspace(min(y), max(y), 100)
X, Y = np.meshgrid(x_grid, y_grid)
Z = np.sin(X**2 + Y**2)
surf = ax.plot_surface(X, Y, Z, cmap='winter', edgecolor='none', alpha=0.8, label="Target function")
ax.legend(['Target surface'])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
ax.set_title('Target function vs Validation data')
ax.legend()
plt.show()

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model1 = tf.keras.Sequential()
model1.add(Dense(32, input_shape=(2,), activation='relu'))
model1.add(Dense(16,  activation='relu'))
model1.add(Dense(1,))

# compile the model choosing optimizer, loss and metrics objects
model1.compile(optimizer='adam', loss='mse', metrics=['mse']) 

model1.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 32)             │            96 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 641 (2.50 KB)
#  Trainable params: 641 (2.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model1.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=20,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.2146 - mse: 0.2146 - val_loss: 0.1137 - val_mse: 0.1137
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 0.1076 - mse: 0.1076 - val_loss: 0.0651 - val_mse: 0.0651
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - loss: 0.0547 - mse: 0.0547 - val_loss: 0.0325 - val_mse: 0.0325
# Epoch 4/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 0.0275 - mse: 0.0275 - val_loss: 0.0203 - val_mse: 0.0203
# Epoch 5/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0153 - val_mse: 0.0153
# Epoch 6/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 7/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 8/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 9/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 10/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 11/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 12/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 13/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 14/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 15/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 16/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 17/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 18/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 19/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 20/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0104 - val_mse: 0.0104

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'], 'go-')
plt.plot(history.history['val_loss'], 'ro-')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.grid('true')
plt.show()

# %%
x_predicted = np.random.uniform(-1.5, 1.5,size=(4000, 2))
y_predicted = model1.predict(x_predicted)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x_predicted[:, 0], x_predicted[:, 1], y_predicted.flatten(), c='blue', s=10)
plt.title("Plot of Model Predictions")

plt.grid(True)
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x16a82f240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 272us/step
